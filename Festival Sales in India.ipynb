# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt #visualizing data

# %%
df=pd.read_csv(r'C:\Users\ahmed\Downloads\EDA project\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
Use the info() to check consistency among the data , are there blank values , are the data types correct

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop=   axis- from which row to start deleting 
           inplace- If False, return a copy. Otherwise, do operation in place and return

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (11251, 13)

# %%
#checking for null values

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
#the amount column has 12 null values
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
sns.countplot(x='Age Group',data=df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='Occupation',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
/// Grouping by Genders

# %%
ax=sns.countplot(x='Gender',data=df)
#///Adding values to the graphs 
for i in ax.containers:
    ax.bar_label(i)

# %%
///Grouping by the amount of purchases

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
From the above two graphs we conclude that more number of females are buying and purchasing power of females is greater

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
///our next analysis will be on Age group

# %%
ax=sns.countplot(x='Age Group',hue='Gender',data=df)
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum()
sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
Conclusion : Out major Customers are Females from the age 26-35 , followed by 36-45

# %%
////Checking total number of orders state wise

# %%
state_orders=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values('Orders',ascending=False).head(10)
sns.barplot(x='State',y='Orders',data=state_orders)
sns.set(rc={'figure.figsize':(15,50)})

# %%
checking amount wise order's rathar than quantity , You will see that kerala was in 8th position but amount wise it falls from top 10

# %%
state_orders=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values('Amount',ascending=False).head(10)
sns.barplot(x='State',y='Amount',data=state_orders)
sns.set(rc={'figure.figsize':(5,10)})

# %%
//Conclusion - Most of the orders are from Uttar Pradesh , Maharashathra, karnataka and their purchasing power is greater as well

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# <strong>MARITAL STATUS</strong>

# %%
ax=sns.countplot(x='Marital_Status',data=df)
for i in ax.containers:
    ax.bar_label(i)
sns.set(rc={'figure.figsize':(5,10)})

# %% [markdown]
# <strong>Occupation</strong>

# %%
sales_state=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=True)
sns.barplot(x='Occupation',y='Amount',data=df)
sns.set(rc={'figure.figsize':(25,5)})

# %%
from the above we see the highest comes from Govt
